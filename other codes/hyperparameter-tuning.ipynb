# %%
# Importing the necessary packages
import pandas as pd
import numpy as np
import keras
from sklearn.preprocessing import StandardScaler

# %%
# load pima indians dataset
dataset = np.loadtxt("../input/prima123/pima-indians-diabetes.data.csv", delimiter=",")

# %%
X = dataset[:,0:8]
y = dataset[:,8]

# %%
# Standardization
a = StandardScaler()
a.fit(X)
X_standardized = a.transform(X)

# %%
pd.DataFrame(X_standardized).describe()
# Out:
#                   0             1             2             3             4  \
# count  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02  7.680000e+02
# mean  -7.748432e-17  3.614007e-18 -1.327244e-17  7.762888e-17 -5.493291e-17
# std    1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00  1.000652e+00
# min   -1.141852e+00 -3.783654e+00 -3.572597e+00 -1.288212e+00 -6.928906e-01
# 25%   -8.448851e-01 -6.852363e-01 -3.673367e-01 -1.288212e+00 -6.928906e-01
# 50%   -2.509521e-01 -1.218877e-01  1.496408e-01  1.545332e-01 -4.280622e-01
# 75%    6.399473e-01  6.057709e-01  5.632228e-01  7.190857e-01  4.120079e-01
# max    3.906578e+00  2.444478e+00  2.734528e+00  4.921866e+00  6.652839e+00
#
#                   5             6             7
# count  7.680000e+02  7.680000e+02  7.680000e+02
# mean   2.972738e-15  1.924387e-15  2.192980e-16
# std    1.000652e+00  1.000652e+00  1.000652e+00
# min   -4.060474e+00 -1.189553e+00 -1.041549e+00
# 25%   -5.955785e-01 -6.889685e-01 -7.862862e-01
# 50%    9.419788e-04 -3.001282e-01 -3.608474e-01
# 75%    5.847705e-01  4.662269e-01  6.602056e-01
# max    4.455807e+00  5.883565e+00  4.063716e+00

# %% [markdown]
# #### Tuning of Hyperparameters :- Batch Size and Epochs

# %%
# Importing the necessary packages
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam

# %%
# create model
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
    model.add(Dense(8, init='uniform', activation='relu'))
    model.add(Dense(1, init='uniform', activation='sigmoid'))
    
    adam=Adam(lr=0.01)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model

# %%
# Create the model
model = KerasClassifier(build_fn = create_model,verbose = 0)
# Define the grid search parameters
batch_size = [10,20,40]
epochs = [10,50,100]
# Make a dictionary of the grid search parameters
param_grid = dict(batch_size = batch_size,epochs = epochs)
# Build and fit the GridSearchCV
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] batch_size=10, epochs=10 ........................................
# [CV] .............. batch_size=10, epochs=10, score=nan, total=   0.1s
# [CV] batch_size=10, epochs=10 ........................................
# [CV] .............. batch_size=10, epochs=10, score=nan, total=   0.0s
# [CV] batch_size=10, epochs=10 ........................................
# [CV] .............. batch_size=10, epochs=10, score=nan, total=   0.0s
# [CV] batch_size=10, epochs=10 ........................................
# [CV] .............. batch_size=10, epochs=10, score=nan, total=   0.0s
# [CV] batch_size=10, epochs=10 ........................................
# [CV] .............. batch_size=10, epochs=10, score=nan, total=   0.0s
# [CV] batch_size=10, epochs=50 ........................................
# [CV] .............. batch_size=10, epochs=50, score=nan, total=   0.0s
# [CV] batch_size=10, epochs=50 ........................................
# [CV] .............. batch_size=10, epochs=50, score=nan, total=   0.0s
# [CV] batch_size=10, epochs=50 ........................................
# [CV] .............. batch_size=10, epochs=50, score=nan, total=   0.0s
# [CV] batch_size=10, epochs=50 ........................................
# [CV] .............. batch_size=10, epochs=50, score=nan, total=   0.0s
# [CV] batch_size=10, epochs=50 ........................................
# [CV] .............. batch_size=10, epochs=50, score=nan, total=   0.0s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ............. batch_size=10, epochs=100, score=nan, total=   0.0s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ............. batch_size=10, epochs=100, score=nan, total=   0.0s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ............. batch_size=10, epochs=100, score=nan, total=   0.0s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ............. batch_size=10, epochs=100, score=nan, total=   0.0s
# [CV] batch_size=10, epochs=100 .......................................
# [CV] ............. batch_size=10, epochs=100, score=nan, total=   0.0s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] .............. batch_size=20, epochs=10, score=nan, total=   0.0s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] .............. batch_size=20, epochs=10, score=nan, total=   0.0s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] .............. batch_size=20, epochs=10, score=nan, total=   0.0s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] .............. batch_size=20, epochs=10, score=nan, total=   0.0s
# [CV] batch_size=20, epochs=10 ........................................
# [CV] .............. batch_size=20, epochs=10, score=nan, total=   0.0s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] .............. batch_size=20, epochs=50, score=nan, total=   0.0s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] .............. batch_size=20, epochs=50, score=nan, total=   0.0s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] .............. batch_size=20, epochs=50, score=nan, total=   0.0s
# [CV] batch_size=20, epochs=50 ........................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:552: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_validation.py", line 531, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 223, in fit
#     return super(KerasClassifier, self).fit(x, y, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py", line 157, in fit
#     self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#   File "<ipython-input-7-aee56e00d4c0>", line 4, in create_model
#     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py", line 1144, in __init__
#     activity_regularizer=activity_regularizer, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/python/training/tracking/base.py", line 457, in _method_wrapper
#     result = method(self, *args, **kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py", line 318, in __init__
#     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#   File "/opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/utils/generic_utils.py", line 778, in validate_kwargs
#     raise TypeError(error_message, kwarg)
# TypeError: ('Keyword argument not understood:', 'init')
#
#   FitFailedWarning)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.1s remaining:    0.0s
# [CV] .............. batch_size=20, epochs=50, score=nan, total=   0.0s
# [CV] batch_size=20, epochs=50 ........................................
# [CV] .............. batch_size=20, epochs=50, score=nan, total=   0.0s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ............. batch_size=20, epochs=100, score=nan, total=   0.0s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ............. batch_size=20, epochs=100, score=nan, total=   0.0s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ............. batch_size=20, epochs=100, score=nan, total=   0.0s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ............. batch_size=20, epochs=100, score=nan, total=   0.0s
# [CV] batch_size=20, epochs=100 .......................................
# [CV] ............. batch_size=20, epochs=100, score=nan, total=   0.0s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] .............. batch_size=40, epochs=10, score=nan, total=   0.0s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] .............. batch_size=40, epochs=10, score=nan, total=   0.0s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] .............. batch_size=40, epochs=10, score=nan, total=   0.0s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] .............. batch_size=40, epochs=10, score=nan, total=   0.0s
# [CV] batch_size=40, epochs=10 ........................................
# [CV] .............. batch_size=40, epochs=10, score=nan, total=   0.0s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] .............. batch_size=40, epochs=50, score=nan, total=   0.0s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] .............. batch_size=40, epochs=50, score=nan, total=   0.0s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] .............. batch_size=40, epochs=50, score=nan, total=   0.0s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] .............. batch_size=40, epochs=50, score=nan, total=   0.0s
# [CV] batch_size=40, epochs=50 ........................................
# [CV] .............. batch_size=40, epochs=50, score=nan, total=   0.0s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ............. batch_size=40, epochs=100, score=nan, total=   0.0s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ............. batch_size=40, epochs=100, score=nan, total=   0.0s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ............. batch_size=40, epochs=100, score=nan, total=   0.0s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ............. batch_size=40, epochs=100, score=nan, total=   0.0s
# [CV] batch_size=40, epochs=100 .......................................
# [CV] ............. batch_size=40, epochs=100, score=nan, total=   0.0s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:    0.3s finished
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-0efede6617b0> in <module>
#       8 # Build and fit the GridSearchCV
#       9 grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
# ---> 10 grid_result = grid.fit(X_standardized,y)
#
# /opt/conda/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     763             refit_start_time = time.time()
#     764             if y is not None:
# --> 765                 self.best_estimator_.fit(X, y, **fit_params)
#     766             else:
#     767                 self.best_estimator_.fit(X, **fit_params)
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     221       raise ValueError('Invalid shape for y: ' + str(y.shape))
#     222     self.n_classes_ = len(self.classes_)
# --> 223     return super(KerasClassifier, self).fit(x, y, **kwargs)
#     224
#     225   def predict(self, x, **kwargs):
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/wrappers/scikit_learn.py in fit(self, x, y, **kwargs)
#     155           **self.filter_sk_params(self.build_fn.__call__))
#     156     else:
# --> 157       self.model = self.build_fn(**self.filter_sk_params(self.build_fn))
#     158
#     159     if (losses.is_categorical_crossentropy(self.model.loss) and
#
# <ipython-input-7-aee56e00d4c0> in create_model()
#       2 def create_model():
#       3     model = Sequential()
# ----> 4     model.add(Dense(12, input_dim=8, init='uniform', activation='relu'))
#       5     model.add(Dense(8, init='uniform', activation='relu'))
#       6     model.add(Dense(1, init='uniform', activation='sigmoid'))
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py in __init__(self, units, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#    1142                **kwargs):
#    1143     super(Dense, self).__init__(
# -> 1144         activity_regularizer=activity_regularizer, **kwargs)
#    1145
#    1146     self.units = int(units) if not isinstance(units, int) else units
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in __init__(self, trainable, name, dtype, dynamic, **kwargs)
#     316     }
#     317     # Validate optional keyword arguments.
# --> 318     generic_utils.validate_kwargs(kwargs, allowed_kwargs)
#     319
#     320     # Mutable properties
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/utils/generic_utils.py in validate_kwargs(kwargs, allowed_kwargs, error_message)
#     776   for kwarg in kwargs:
#     777     if kwarg not in allowed_kwargs:
# --> 778       raise TypeError(error_message, kwarg)
#     779
#     780
#
# TypeError: ('Keyword argument not understood:', 'init')

# %% [markdown]
# #### Tuning of Hyperparameters:- Learning rate and Drop out rate

# %%
from keras.layers import Dropout

# Defining the model

def create_model(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4,input_dim = 8,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]

# Make a dictionary of the grid search parameters

param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.766, total=   1.3s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.714, total=   0.9s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.1s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.630, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.9s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.824, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.001 ...........................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    3.8s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.001, score=0.725, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.6s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.760, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    5.5s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.695, total=   1.2s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    6.7s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.766, total=   0.9s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    7.5s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.856, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.01 ............................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    8.3s remaining:    0.0s
# [CV]  dropout_rate=0.0, learning_rate=0.01, score=0.752, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.727, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.688, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.721, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.830, total=   0.8s
# [CV] dropout_rate=0.0, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.0, learning_rate=0.1, score=0.758, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.766, total=   0.9s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.675, total=   1.2s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.753, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.824, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.1, learning_rate=0.001, score=0.771, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.760, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.753, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.760, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.830, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.1, learning_rate=0.01, score=0.752, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.773, total=   1.2s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.708, total=   0.9s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.779, total=   0.9s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.797, total=   0.8s
# [CV] dropout_rate=0.1, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.1, learning_rate=0.1, score=0.758, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.649, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.688, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.682, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.752, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.001 ...........................
# [CV]  dropout_rate=0.2, learning_rate=0.001, score=0.745, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.734, total=   1.2s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.734, total=   0.9s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.753, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.830, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.01 ............................
# [CV]  dropout_rate=0.2, learning_rate=0.01, score=0.758, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.766, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.714, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.734, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.837, total=   0.8s
# [CV] dropout_rate=0.2, learning_rate=0.1 .............................
# [CV] . dropout_rate=0.2, learning_rate=0.1, score=0.706, total=   0.8s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:   39.3s finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7708853125572205, using {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.731881844997406,0.06377491694672753 with: {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.7657244682312012,0.05186835804868581 with: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.7449198007583618,0.04800832625214777 with: {'dropout_rate': 0.0, 'learning_rate': 0.1}
# 0.7579152822494507,0.04773889956891768 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# 0.7708853125572205,0.029773939892504188 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.7630591630935669,0.03036878267988064 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# 0.7032425165176391,0.039191548049363145 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# 0.7618029117584229,0.03554793339288338 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# 0.7513538837432862,0.0474121631751535 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %% [markdown]
# #### Tuning of Hyperparameters:- Activation Function and Kernel Initializer

# %%
# Defining the model

def create_model(activation_function,init):
    model = Sequential()
    model.add(Dense(8,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']

# Make a dictionary of the grid search parameters
param_grids = dict(activation_function = activation_function,init = init)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  activation_function=softmax, init=uniform, score=0.649, total=   1.5s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.5s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.584, total=   0.9s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    2.3s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.630, total=   0.9s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    3.2s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.745, total=   0.8s
# [CV] activation_function=softmax, init=uniform .......................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    4.1s remaining:    0.0s
# [CV]  activation_function=softmax, init=uniform, score=0.647, total=   0.8s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.9s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.649, total=   0.8s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    5.7s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.416, total=   0.8s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    6.6s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.630, total=   0.8s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    7.4s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.745, total=   0.8s
# [CV] activation_function=softmax, init=normal ........................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    8.2s remaining:    0.0s
# [CV]  activation_function=softmax, init=normal, score=0.647, total=   0.9s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.649, total=   1.4s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.416, total=   0.9s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.630, total=   0.8s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.745, total=   0.8s
# [CV] activation_function=softmax, init=zero ..........................
# [CV]  activation_function=softmax, init=zero, score=0.647, total=   0.8s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.766, total=   0.8s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.584, total=   0.8s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.630, total=   0.8s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.797, total=   0.8s
# [CV] activation_function=relu, init=uniform ..........................
# [CV]  activation_function=relu, init=uniform, score=0.647, total=   0.8s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.747, total=   0.8s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.682, total=   1.4s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.630, total=   0.9s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.824, total=   0.9s
# [CV] activation_function=relu, init=normal ...........................
# [CV]  activation_function=relu, init=normal, score=0.719, total=   0.8s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.649, total=   0.8s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.584, total=   0.8s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.630, total=   0.8s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.745, total=   0.8s
# [CV] activation_function=relu, init=zero .............................
# [CV] . activation_function=relu, init=zero, score=0.647, total=   0.8s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.766, total=   0.8s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.688, total=   0.8s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.753, total=   1.4s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.830, total=   0.9s
# [CV] activation_function=tanh, init=uniform ..........................
# [CV]  activation_function=tanh, init=uniform, score=0.784, total=   0.9s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.753, total=   0.8s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.695, total=   0.8s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.740, total=   0.8s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.830, total=   0.8s
# [CV] activation_function=tanh, init=normal ...........................
# [CV]  activation_function=tanh, init=normal, score=0.765, total=   0.8s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.649, total=   0.8s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.584, total=   0.8s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.630, total=   0.8s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.745, total=   0.8s
# [CV] activation_function=tanh, init=zero .............................
# [CV] . activation_function=tanh, init=zero, score=0.647, total=   1.4s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.753, total=   0.9s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.695, total=   0.9s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.753, total=   0.8s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.824, total=   0.8s
# [CV] activation_function=linear, init=uniform ........................
# [CV]  activation_function=linear, init=uniform, score=0.765, total=   0.8s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.753, total=   0.8s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.708, total=   0.8s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.773, total=   0.8s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.843, total=   0.8s
# [CV] activation_function=linear, init=normal .........................
# [CV]  activation_function=linear, init=normal, score=0.752, total=   0.8s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.649, total=   1.3s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.584, total=   0.9s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.630, total=   0.9s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.745, total=   0.9s
# [CV] activation_function=linear, init=zero ...........................
# [CV]  activation_function=linear, init=zero, score=0.647, total=   0.8s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:   53.4s finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7657074928283691, using {'activation_function': 'linear', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'softmax', 'init': 'uniform'}
# 0.6173924148082733,0.10871275688841411 with: {'activation_function': 'softmax', 'init': 'normal'}
# 0.6173924148082733,0.10871275688841411 with: {'activation_function': 'softmax', 'init': 'zero'}
# 0.6849927783012391,0.08225024863558322 with: {'activation_function': 'relu', 'init': 'uniform'}
# 0.7201850533485412,0.0648324734187861 with: {'activation_function': 'relu', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'relu', 'init': 'zero'}
# 0.7644342541694641,0.046099197463484995 with: {'activation_function': 'tanh', 'init': 'uniform'}
# 0.7566165924072266,0.0437257569411756 with: {'activation_function': 'tanh', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'tanh', 'init': 'zero'}
# 0.7579067945480347,0.040933605217224146 with: {'activation_function': 'linear', 'init': 'uniform'}
# 0.7657074928283691,0.0441636931013981 with: {'activation_function': 'linear', 'init': 'normal'}
# 0.6511586427688598,0.05244526932680711 with: {'activation_function': 'linear', 'init': 'zero'}

# %% [markdown]
# #### Tuning of Hyperparameter :-Number of Neurons in activation layer

# %%
# Defining the model

def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Define the grid search parameters

neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ................ neuron1=4, neuron2=2, score=0.747, total=   0.8s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.662, total=   0.9s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.7s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.721, total=   0.8s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    2.6s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.817, total=   0.8s
# [CV] neuron1=4, neuron2=2 ............................................
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    3.4s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=2, score=0.745, total=   0.9s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.2s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.760, total=   0.8s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    5.1s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.695, total=   0.8s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    5.9s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.727, total=   1.5s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    7.4s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.817, total=   1.0s
# [CV] neuron1=4, neuron2=4 ............................................
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    8.4s remaining:    0.0s
# [CV] ................ neuron1=4, neuron2=4, score=0.745, total=   0.9s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.747, total=   0.9s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.669, total=   0.9s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.747, total=   0.8s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.830, total=   0.8s
# [CV] neuron1=4, neuron2=8 ............................................
# [CV] ................ neuron1=4, neuron2=8, score=0.752, total=   0.8s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.753, total=   0.8s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.714, total=   0.9s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.753, total=   0.8s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.817, total=   0.8s
# [CV] neuron1=8, neuron2=2 ............................................
# [CV] ................ neuron1=8, neuron2=2, score=0.765, total=   0.8s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.760, total=   1.5s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.708, total=   0.9s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.753, total=   0.9s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.810, total=   0.9s
# [CV] neuron1=8, neuron2=4 ............................................
# [CV] ................ neuron1=8, neuron2=4, score=0.765, total=   0.8s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.760, total=   0.9s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.714, total=   0.8s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.766, total=   0.8s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.830, total=   0.8s
# [CV] neuron1=8, neuron2=8 ............................................
# [CV] ................ neuron1=8, neuron2=8, score=0.765, total=   0.8s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.760, total=   0.8s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.708, total=   0.8s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.760, total=   0.8s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.810, total=   1.5s
# [CV] neuron1=16, neuron2=2 ...........................................
# [CV] ............... neuron1=16, neuron2=2, score=0.765, total=   0.9s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.766, total=   0.9s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.708, total=   0.9s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.760, total=   0.9s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.830, total=   0.9s
# [CV] neuron1=16, neuron2=4 ...........................................
# [CV] ............... neuron1=16, neuron2=4, score=0.771, total=   0.8s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.773, total=   0.8s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.727, total=   0.8s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.753, total=   0.8s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.817, total=   0.8s
# [CV] neuron1=16, neuron2=8 ...........................................
# [CV] ............... neuron1=16, neuron2=8, score=0.739, total=   0.8s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed:   40.2s finished

# %%
# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.7670146822929382, using {'neuron1': 16, 'neuron2': 4}
# 0.7383923411369324,0.04977458343422404 with: {'neuron1': 4, 'neuron2': 2}
# 0.748781943321228,0.040404460012784 with: {'neuron1': 4, 'neuron2': 4}
# 0.7488074183464051,0.05102055190956904 with: {'neuron1': 4, 'neuron2': 8}
# 0.7604957103729248,0.03301569573204633 with: {'neuron1': 8, 'neuron2': 2}
# 0.7591885209083558,0.032668459722358184 with: {'neuron1': 8, 'neuron2': 4}
# 0.7670061945915222,0.036917716743523406 with: {'neuron1': 8, 'neuron2': 8}
# 0.7604872226715088,0.032535235100431235 with: {'neuron1': 16, 'neuron2': 2}
# 0.7670146822929382,0.03886923020055161 with: {'neuron1': 16, 'neuron2': 4}
# 0.7617604613304139,0.03153095599423095 with: {'neuron1': 16, 'neuron2': 8}

# %% [markdown]
# #### Training model with optimum values of Hyperparameters

# %%
from sklearn.metrics import classification_report, accuracy_score

# Defining the model

def create_model():
    model = Sequential()
    model.add(Dense(16,input_dim = 8,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 16,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001) #sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

# Fitting the model

model.fit(X_standardized,y)

# Predicting using trained model

y_predict = model.predict(X_standardized)

# Printing the metrics
print(accuracy_score(y,y_predict))
# Out:
# 0.7799479166666666

# %% [markdown]
# # Hyperparameters all at once

# %% [markdown]
# The hyperparameter optimization was carried out by taking 2 hyperparameters at once. We may have missed the best values. The performance can be further improved by finding the optimum values of hyperparameters all at once given by the code snippet below.
# #### This process is computationally expensive.

# %%
def create_model(learning_rate,dropout_rate,activation_function,init,neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 8,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# Create the model

model = KerasClassifier(build_fn = create_model,verbose = 0)

# Define the grid search parameters

batch_size = [10,20,40]
epochs = [10,50,100]
learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]
activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']
neuron1 = [4,8,16]
neuron2 = [2,4,8]

# Make a dictionary of the grid search parameters

param_grids = dict(batch_size = batch_size,epochs = epochs,learning_rate = learning_rate,dropout_rate = dropout_rate,
                   activation_function = activation_function,init = init,neuron1 = neuron1,neuron2 = neuron2)

# Build and fit the GridSearchCV

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)

# Summarize the results
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
